# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("csv/총 분석.csv")

# %% [markdown]
# ## * 히트맵

# %%
# 맑음 고딕을 한 이유 : 실행시 한글이 안 깨짐
# 전체 특징들과 음식물쓰레기의 상관관계를 히트맵으로 표
plt.rcParams['font.family']='Malgun Gothic'
데이터1=df.drop(['base_date'],axis=1)
sns.heatmap(히트맵데이터1.corr())
plt.show()

# %%
# 카드와 음식물쓰레기의 상관관계를 히트맵으로 표현
데이터2=df.drop(['resid_reg_pop','foreign_pop','total_pop','내국인R', '내국인W', '내국인V', '내국인관광W','내국인관광V', '장기외국인R', '장기외국인W', '장기외국인V', '단기외국인V'],axis=1)
sns.heatmap(히트맵데이터2.corr())
plt.rcParams['font.family']='Malgun Gothic'
plt.show()

# %%
# 유동인구 + 거주인구가 음식물 쓰레기와 가지는 상관관계를 히트맵으로 표현
데이터3=df.drop(['간식', '농축수산물', '마트/슈퍼마켓', '배달', '부페', '식품','아시아음식', '양식', '주점및주류판매', '패스트푸드', '한식'],axis=1)
sns.heatmap(히트맵데이터3.corr())
plt.rcParams['font.family']='Malgun Gothic'
plt.show()

# %%
# 전체 특징들과 음식물쓰레기의 상관관계
데이터1.corr()
# Out:
#                    em_g      내국인R      내국인W      내국인V    내국인관광W    내국인관광V  \
# em_g           1.000000  0.872298  0.796817  0.824706  0.572103  0.299968
# 내국인R           0.872298  1.000000  0.888143  0.891535  0.809495  0.557713
# 내국인W           0.796817  0.888143  1.000000  0.903746  0.697256  0.536246
# 내국인V           0.824706  0.891535  0.903746  1.000000  0.657557  0.470580
# 내국인관광W         0.572103  0.809495  0.697256  0.657557  1.000000  0.745875
# 내국인관광V         0.299968  0.557713  0.536246  0.470580  0.745875  1.000000
# 장기외국인R         0.600457  0.736623  0.687346  0.582733  0.709106  0.578428
# 장기외국인W         0.415137  0.512214  0.560676  0.477855  0.524041  0.565477
# 장기외국인V         0.228761  0.364580  0.353187  0.368333  0.477200  0.593689
# 단기외국인V         0.235994  0.241367  0.366302  0.290246  0.199341  0.466987
# resid_reg_pop  0.888455  0.977174  0.842048  0.866837  0.780817  0.542918
# foreign_pop    0.496605  0.618907  0.506311  0.416428  0.680465  0.551749
# ...

# %%
# # 카드와 음식물쓰레기의 상관관계
데이터2.corr()
# Out:
#              em_g        간식     농축수산물   마트/슈퍼마켓        배달        부페        식품  \
# em_g     1.000000  0.941584  0.822095  0.947076  0.636266  0.744577  0.795958
# 간식       0.941584  1.000000  0.850971  0.972106  0.678128  0.769743  0.878126
# 농축수산물    0.822095  0.850971  1.000000  0.796813  0.642734  0.651543  0.738600
# 마트/슈퍼마켓  0.947076  0.972106  0.796813  1.000000  0.687761  0.747215  0.826726
# 배달       0.636266  0.678128  0.642734  0.687761  1.000000  0.258455  0.684908
# 부페       0.744577  0.769743  0.651543  0.747215  0.258455  1.000000  0.636964
# 식품       0.795958  0.878126  0.738600  0.826726  0.684908  0.636964  1.000000
# 아시아음식    0.934157  0.986408  0.842380  0.968962  0.680169  0.779937  0.901776
# 양식       0.889299  0.940921  0.781935  0.899212  0.552192  0.748252  0.822241
# 주점및주류판매  0.900497  0.929777  0.800366  0.929713  0.724150  0.712101  0.841362
# 패스트푸드    0.941716  0.988991  0.837900  0.966644  0.627938  0.794449  0.890252
# ...

# %%
# 유동인구 + 거주인구가 음식물 쓰레기와 가지는 상관관계
데이터3.corr()
# Out:
#                    em_g      내국인R      내국인W      내국인V    내국인관광W    내국인관광V  \
# em_g           1.000000  0.872298  0.796817  0.824706  0.572103  0.299968
# 내국인R           0.872298  1.000000  0.888143  0.891535  0.809495  0.557713
# 내국인W           0.796817  0.888143  1.000000  0.903746  0.697256  0.536246
# 내국인V           0.824706  0.891535  0.903746  1.000000  0.657557  0.470580
# 내국인관광W         0.572103  0.809495  0.697256  0.657557  1.000000  0.745875
# 내국인관광V         0.299968  0.557713  0.536246  0.470580  0.745875  1.000000
# 장기외국인R         0.600457  0.736623  0.687346  0.582733  0.709106  0.578428
# 장기외국인W         0.415137  0.512214  0.560676  0.477855  0.524041  0.565477
# 장기외국인V         0.228761  0.364580  0.353187  0.368333  0.477200  0.593689
# 단기외국인V         0.235994  0.241367  0.366302  0.290246  0.199341  0.466987
# resid_reg_pop  0.888455  0.977174  0.842048  0.866837  0.780817  0.542918
# foreign_pop    0.496605  0.618907  0.506311  0.416428  0.680465  0.551749
# ...
