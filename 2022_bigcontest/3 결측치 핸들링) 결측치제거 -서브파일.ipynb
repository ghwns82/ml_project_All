# %%
import pandas as pd
import numpy as np
import os
import random
from copy import deepcopy
import math
from itertools import product
import pickle
import joblib
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# %%
idx_df=pd.read_csv('./customData/idx.csv',index_col=0)
idx_df.columns=['idx','user_id']

# %%
merged_df=pd.read_csv('./customData/work_target.csv',index_col=0)

# %%
# result=pd.read_csv('./customData/imcompleted_merged_ver0_5.csv',index_col=0)

# %%
idx_df[idx_df['user_id']>=453640]
# Out:
#              idx  user_id
# 163664   6968268   453640
# 163665   6968274   453641
# 163666   6968280   453642
# 163667   6968296   453643
# 163668   6968297   453645
# ...          ...      ...
# 317462  13527092   879692
# 317463  13527152   879693
# 317464  13527177   879695
# 317465  13527182   879696
# 317466  13527214   879697
#
# [153803 rows x 2 columns]

# %%
idx_df.loc[163665][0]
# Out:
# 6968274

# %%
start = 163665

# %%
result = pd.DataFrame()
for i in tqdm(range(start, 20_0000)):
    idx=idx_df.loc[i][0]
    result= pd.concat([result, merged_df.iloc[idx:idx_df.loc[i+1][0]].fillna(method='ffill').fillna(method='bfill')])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 36335/36335 [31:45<00:00, 19.07it/s]

# %%
result.to_csv('./customData/result1.csv')

# %%
start = 30_0000

# %%
result = pd.DataFrame()
for i in tqdm(range(start, 317467)):
    idx=idx_df.loc[i][0]
    result= pd.concat([result, merged_df.iloc[idx:idx_df.loc[i+1][0]].fillna(method='ffill').fillna(method='bfill')])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████▉| 17466/17467 [09:36<00:00, 30.30it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 317467
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_101/1602509268.py in <module>
#       2 for i in tqdm(range(start, 317467)):
#       3     idx=idx_df.loc[i][0]
# ----> 4     result= pd.concat([result, merged_df.iloc[idx:idx_df.loc[i+1][0]].fillna(method='ffill').fillna(method='bfill')])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 317467

# %%
result
# Out:
#             index  application_id  user_id  birth_year  gender  \
# 12785975  7521949         2021754   831212      1990.0     0.0
# 12785976  7521932         2021754   831212      1990.0     0.0
# 12785977  7521935         2021754   831212      1990.0     0.0
# 12785978  7521938         2021754   831212      1990.0     0.0
# 12785979  7521939         2021754   831212      1990.0     0.0
# ...           ...             ...      ...         ...     ...
# 13527209   589987         1856758   879696      1997.0     1.0
# 13527210   589990         1856758   879696      1997.0     1.0
# 13527211   589995         1856758   879696      1997.0     1.0
# 13527212   589989         1856758   879696      1997.0     1.0
# 13527213   589998         1856758   879696      1997.0     1.0
#
#                   insert_time  credit_score  yearly_income   income_type  \
# 12785975  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# 12785976  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# 12785977  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# 12785978  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# 12785979  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# ...                       ...           ...            ...           ...
# 13527209  2022-03-14 05:40:38         610.0     37000000.0  EARNEDINCOME
# 13527210  2022-03-14 05:40:38         610.0     37000000.0  EARNEDINCOME
# 13527211  2022-03-14 05:40:38         610.0     37000000.0  EARNEDINCOME
# 13527212  2022-03-14 05:40:38         610.0     37000000.0  EARNEDINCOME
# 13527213  2022-03-14 05:40:38         610.0     37000000.0  EARNEDINCOME
#
#           company_enter_month  ... personal_rehabilitation_yn  \
# 12785975             201808.0  ...                        NaN
# 12785976             201808.0  ...                        NaN
# 12785977             201808.0  ...                        NaN
# 12785978             201808.0  ...                        NaN
# 12785979             201808.0  ...                        NaN
# ...                       ...  ...                        ...
# 13527209             202110.0  ...                        NaN
# 13527210             202110.0  ...                        NaN
# 13527211             202110.0  ...                        NaN
# 13527212             202110.0  ...                        NaN
# 13527213             202110.0  ...                        NaN
#
#          personal_rehabilitation_complete_yn  existing_loan_cnt  \
# 12785975                                 NaN                2.0
# 12785976                                 NaN                2.0
# 12785977                                 NaN                2.0
# 12785978                                 NaN                2.0
# 12785979                                 NaN                2.0
# ...                                      ...                ...
# 13527209                                 NaN                3.0
# 13527210                                 NaN                3.0
# 13527211                                 NaN                3.0
# 13527212                                 NaN                3.0
# 13527213                                 NaN                3.0
#
#          existing_loan_amt  loanapply_insert_time  bank_id  product_id  \
# 12785975        12000000.0    2022-04-26 14:47:20       59         150
# 12785976        12000000.0    2022-04-26 14:47:21       50         142
# 12785977        12000000.0    2022-04-26 14:47:21       10         149
# 12785978        12000000.0    2022-04-26 14:47:21       38         223
# 12785979        12000000.0    2022-04-26 14:47:21       33         110
# ...                    ...                    ...      ...         ...
# 13527209        20000000.0    2022-03-14 05:40:45       19         127
# 13527210        20000000.0    2022-03-14 05:40:46       23         108
# 13527211        20000000.0    2022-03-14 05:40:50       22         164
# 13527212        20000000.0    2022-03-14 05:40:56       49          39
# 13527213        20000000.0    2022-03-14 05:40:56       49         136
#
#           loan_limit loan_rate  is_applied
# 12785975  30000000.0      17.6         0.0
# 12785976  29000000.0      19.9         0.0
# 12785977  15000000.0      18.5         0.0
# 12785978  13000000.0      16.6         0.0
# 12785979  17000000.0      15.6         0.0
# ...              ...       ...         ...
# 13527209   9000000.0       9.4         0.0
# 13527210  10000000.0      16.5         0.0
# 13527211   9000000.0       8.4         0.0
# 13527212  11000000.0      16.1         1.0
# 13527213   9000000.0       6.5         0.0
#
# [741239 rows x 24 columns]

# %%
result= pd.concat([result, merged_df.iloc[idx:].fillna(method='ffill').fillna(method='bfill')])

# %%
result
# Out:
#             index  application_id  user_id  birth_year  gender  \
# 12785975  7521949         2021754   831212      1990.0     0.0
# 12785976  7521932         2021754   831212      1990.0     0.0
# 12785977  7521935         2021754   831212      1990.0     0.0
# 12785978  7521938         2021754   831212      1990.0     0.0
# 12785979  7521939         2021754   831212      1990.0     0.0
# ...           ...             ...      ...         ...     ...
# 13527245  3912338         1543548   879697      1962.0     1.0
# 13527246  3912345         1543548   879697      1962.0     1.0
# 13527247  3912339         1543548   879697      1962.0     1.0
# 13527248  3912332         1543548   879697      1962.0     1.0
# 13527249  3912346         1543548   879697      1962.0     1.0
#
#                   insert_time  credit_score  yearly_income   income_type  \
# 12785975  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# 12785976  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# 12785977  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# 12785978  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# 12785979  2022-04-26 14:47:20         590.0     26000000.0  EARNEDINCOME
# ...                       ...           ...            ...           ...
# 13527245  2022-05-10 20:40:52           NaN     70000000.0  EARNEDINCOME
# 13527246  2022-05-10 20:40:52           NaN     70000000.0  EARNEDINCOME
# 13527247  2022-05-10 20:40:52           NaN     70000000.0  EARNEDINCOME
# 13527248  2022-05-10 20:40:52           NaN     70000000.0  EARNEDINCOME
# 13527249  2022-05-10 20:40:52           NaN     70000000.0  EARNEDINCOME
#
#           company_enter_month  ... personal_rehabilitation_yn  \
# 12785975             201808.0  ...                        NaN
# 12785976             201808.0  ...                        NaN
# 12785977             201808.0  ...                        NaN
# 12785978             201808.0  ...                        NaN
# 12785979             201808.0  ...                        NaN
# ...                       ...  ...                        ...
# 13527245             202204.0  ...                        0.0
# 13527246             202204.0  ...                        0.0
# 13527247             202204.0  ...                        0.0
# 13527248             202204.0  ...                        0.0
# 13527249             202204.0  ...                        0.0
#
#          personal_rehabilitation_complete_yn  existing_loan_cnt  \
# 12785975                                 NaN                2.0
# 12785976                                 NaN                2.0
# 12785977                                 NaN                2.0
# 12785978                                 NaN                2.0
# 12785979                                 NaN                2.0
# ...                                      ...                ...
# 13527245                                 NaN                NaN
# 13527246                                 NaN                NaN
# 13527247                                 NaN                NaN
# 13527248                                 NaN                NaN
# 13527249                                 NaN                NaN
#
#          existing_loan_amt  loanapply_insert_time  bank_id  product_id  \
# 12785975        12000000.0    2022-04-26 14:47:20       59         150
# 12785976        12000000.0    2022-04-26 14:47:21       50         142
# 12785977        12000000.0    2022-04-26 14:47:21       10         149
# 12785978        12000000.0    2022-04-26 14:47:21       38         223
# 12785979        12000000.0    2022-04-26 14:47:21       33         110
# ...                    ...                    ...      ...         ...
# 13527245               NaN    2022-05-10 20:40:55       64         254
# 13527246               NaN    2022-05-10 20:40:55       12          35
# 13527247               NaN    2022-05-10 20:41:07       52         187
# 13527248               NaN    2022-05-10 20:41:10       55         186
# 13527249               NaN    2022-05-10 20:41:11       34         215
#
#           loan_limit loan_rate  is_applied
# 12785975  30000000.0      17.6         0.0
# 12785976  29000000.0      19.9         0.0
# 12785977  15000000.0      18.5         0.0
# 12785978  13000000.0      16.6         0.0
# 12785979  17000000.0      15.6         0.0
# ...              ...       ...         ...
# 13527245  28000000.0       6.9         0.0
# 13527246  23000000.0       9.2         0.0
# 13527247   3000000.0       5.4         0.0
# 13527248  50000000.0      10.6         0.0
# 13527249  34000000.0      11.9         0.0
#
# [741275 rows x 24 columns]

# %%
result.to_csv('./customData/result4.csv')
